# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

df = pd.read_csv('middleSchoolData.csv')
df = df.dropna()


#To find the independent variables in terms of acceptances
df1 = df.copy()
accepts = df1['acceptances']
df1 = df1.drop(["acceptances"], axis=1)

X = df1.loc[:, 'applications':'school_size']
y = accepts
X_5 = df1[['applications','school_size']]


X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()

print(est2.summary())

#To find regression for achieving high scores on objective measures of achievement
df2 = df.copy()
df2 = df2.drop(['school_name'], axis=1)
df2 = df2.drop(['dbn'], axis=1)
df2 = (df2 - df2.mean())/df2.std()

X_1 = df2.loc[:, 'applications':'school_size']
objAchievement = (df2['student_achievement'] + df2['reading_scores_exceed'] + df2['math_scores_exceed'])/3
y2 = objAchievement

#run model
X2 = sm.add_constant(X_1)
est_1 = sm.OLS(y2, X2)
est_2 = est_1.fit()

print(est_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            acceptances   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     60.22
# Date:                Wed, 19 May 2021   Prob (F-statistic):          2.77e-105
# Time:                        12:54:46   Log-Likelihood:                -1780.6
# No. Observations:                 449   AIC:                             3599.
# Df Residuals:                     430   BIC:                             3677.
# Df Model:                          18
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                         -540.0443    937.267     -0.576      0.565   -2382.239    1302.150
# applications                     0.3109      0.015     21.118      0.000       0.282       0.340
# per_pupil_spending           -5.563e-05      0.000     -0.238      0.812      -0.001       0.000
# avg_class_size                   0.0542      0.165      0.328      0.743      -0.271       0.379
# asian_percent                    5.6506      9.376      0.603      0.547     -12.777      24.078
# black_percent                    5.5228      9.371      0.589      0.556     -12.896      23.941
# hispanic_percent                 5.5375      9.371      0.591      0.555     -12.882      23.957
# multiple_percent                 5.9533      9.364      0.636      0.525     -12.451      24.358
# white_percent                    5.5640      9.371      0.594      0.553     -12.854      23.982
# rigorous_instruction            -1.4650      1.516     -0.966      0.335      -4.445       1.515
# collaborative_teachers           1.3726      1.786      0.768      0.443      -2.138       4.884
# supportive_environment           1.1674      1.638      0.713      0.476      -2.052       4.387
# effective_school_leadership     -1.5683      1.810     -0.867      0.387      -5.125       1.989
# strong_family_community_ties     1.9853      1.410      1.408      0.160      -0.786       4.757
# trust                           -1.0890      1.873     -0.581      0.561      -4.770       2.592
# disability_percent              -0.1121      0.132     -0.850      0.396      -0.371       0.147
# poverty_percent                 -0.1382      0.075     -1.852      0.065      -0.285       0.008
# ESL_percent                      0.0159      0.076      0.207      0.836      -0.134       0.166
# school_size                     -0.0152      0.003     -5.669      0.000      -0.020      -0.010
# ==============================================================================
# Omnibus:                      393.779   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17513.239
# Skew:                           3.477   Prob(JB):                         0.00
# Kurtosis:                      32.795   Cond. No.                     3.21e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.757
# Method:                 Least Squares   F-statistic:                     74.51
# Date:                Wed, 19 May 2021   Prob (F-statistic):          9.36e-123
# Time:                        12:54:46   Log-Likelihood:                -240.61
# No. Observations:                 449   AIC:                             521.2
# Df Residuals:                     429   BIC:                             603.4
# Df Model:                          19
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                         4.129e-16      0.020   2.07e-14      1.000      -0.039       0.039
# applications                     0.0383      0.046      0.838      0.403      -0.052       0.128
# acceptances                      0.0432      0.038      1.152      0.250      -0.031       0.117
# per_pupil_spending               0.0012      0.029      0.041      0.967      -0.057       0.059
# avg_class_size                   0.0277      0.026      1.067      0.287      -0.023       0.079
# asian_percent                    2.1163      5.008      0.423      0.673      -7.728      11.960
# black_percent                    3.0728      8.174      0.376      0.707     -12.994      19.140
# hispanic_percent                 3.1095      7.948      0.391      0.696     -12.512      18.731
# multiple_percent                 0.3095      0.747      0.414      0.679      -1.159       1.778
# white_percent                    2.3338      5.644      0.414      0.679      -8.759      13.427
# rigorous_instruction             0.0987      0.032      3.047      0.002       0.035       0.162
# collaborative_teachers          -0.0205      0.038     -0.536      0.592      -0.096       0.055
# supportive_environment           0.2195      0.031      7.191      0.000       0.159       0.279
# effective_school_leadership     -0.0438      0.034     -1.279      0.202      -0.111       0.024
# strong_family_community_ties     0.0009      0.030      0.028      0.977      -0.059       0.061
# trust                            0.0267      0.035      0.762      0.447      -0.042       0.096
# disability_percent              -0.1237      0.031     -4.049      0.000      -0.184      -0.064
# poverty_percent                 -0.1768      0.049     -3.634      0.000      -0.272      -0.081
# ESL_percent                     -0.1282      0.029     -4.430      0.000      -0.185      -0.071
# school_size                     -0.0381      0.035     -1.090      0.276      -0.107       0.031
# ==============================================================================
# Omnibus:                       66.884   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              203.712
# Skew:                           0.683   Prob(JB):                     5.82e-45
# Kurtosis:                       6.004   Cond. No.                     1.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X2 = sm.add_constant(X_1)
est_1 = sm.OLS(y2, X2)
est_2 = est.fit()

print(est_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            acceptances   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     60.22
# Date:                Wed, 19 May 2021   Prob (F-statistic):          2.77e-105
# Time:                        12:06:27   Log-Likelihood:                -1780.6
# No. Observations:                 449   AIC:                             3599.
# Df Residuals:                     430   BIC:                             3677.
# Df Model:                          18
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                         -540.0443    937.267     -0.576      0.565   -2382.239    1302.150
# applications                     0.3109      0.015     21.118      0.000       0.282       0.340
# per_pupil_spending           -5.563e-05      0.000     -0.238      0.812      -0.001       0.000
# avg_class_size                   0.0542      0.165      0.328      0.743      -0.271       0.379
# asian_percent                    5.6506      9.376      0.603      0.547     -12.777      24.078
# black_percent                    5.5228      9.371      0.589      0.556     -12.896      23.941
# hispanic_percent                 5.5375      9.371      0.591      0.555     -12.882      23.957
# multiple_percent                 5.9533      9.364      0.636      0.525     -12.451      24.358
# white_percent                    5.5640      9.371      0.594      0.553     -12.854      23.982
# rigorous_instruction            -1.4650      1.516     -0.966      0.335      -4.445       1.515
# collaborative_teachers           1.3726      1.786      0.768      0.443      -2.138       4.884
# supportive_environment           1.1674      1.638      0.713      0.476      -2.052       4.387
# effective_school_leadership     -1.5683      1.810     -0.867      0.387      -5.125       1.989
# strong_family_community_ties     1.9853      1.410      1.408      0.160      -0.786       4.757
# trust                           -1.0890      1.873     -0.581      0.561      -4.770       2.592
# disability_percent              -0.1121      0.132     -0.850      0.396      -0.371       0.147
# poverty_percent                 -0.1382      0.075     -1.852      0.065      -0.285       0.008
# ESL_percent                      0.0159      0.076      0.207      0.836      -0.134       0.166
# school_size                     -0.0152      0.003     -5.669      0.000      -0.020      -0.010
# ==============================================================================
# Omnibus:                      393.779   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17513.239
# Skew:                           3.477   Prob(JB):                         0.00
# Kurtosis:                      32.795   Cond. No.                     3.21e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df = pd.read_csv("middleSchoolData.csv")  
df= df.dropna()
dfx=(df-df.mean())/df.std()

y2 = dfx["student_achievement"] + dfx["reading_scores_exceed"] + dfx["math_scores_exceed"]
y2=y2/3


df1 = df

df1 = df1.drop(["acceptances"], axis=1)

X1 = df1.loc[:, "applications":"school_size"]
X2 = df[["applications","school_size"]]
X3 = df[["applications","rigorous_instruction", "supportive_environment", "disability_percent","poverty_percent"]]


y= df["acceptances"]
#model.fit(X, y)
X = sm.add_constant(X3)
result = sm.OLS(y2, X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     218.9
# Date:                Wed, 19 May 2021   Prob (F-statistic):          3.06e-117
# Time:                        13:27:44   Log-Likelihood:                -288.73
# No. Observations:                 449   AIC:                             589.5
# Df Residuals:                     443   BIC:                             614.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0972      0.214     -0.454      0.650      -0.518       0.324
# applications               0.0024      0.000      6.682      0.000       0.002       0.003
# rigorous_instruction       0.1504      0.045      3.352      0.001       0.062       0.239
# supportive_environment     0.4066      0.050      8.078      0.000       0.308       0.505
# disability_percent        -0.0212      0.004     -5.929      0.000      -0.028      -0.014
# poverty_percent           -0.0193      0.001    -15.325      0.000      -0.022      -0.017
# ==============================================================================
# Omnibus:                       30.316   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.286
# Skew:                           0.427   Prob(JB):                     9.88e-13
# Kurtosis:                       4.491   Cond. No.                         995.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
